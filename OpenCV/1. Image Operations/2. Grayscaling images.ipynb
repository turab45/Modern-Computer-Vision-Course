# %% [markdown]
# # Grayscaling images

# %%
# imports
import cv2
import matplotlib.pyplot as plt

# %%
# imshow function
def imshow(title = "", image = None, size = 10):
  h, w = image.shape[0], image.shape[1]
  aspect_ratio = w/h
  plt.figure(figsize=(size * aspect_ratio, size))
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()


# download & unzip images
# !wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# !unzip -qq images.zip
# Out:
# --2022-06-04 06:01:42--  https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# Resolving moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)... 52.95.150.158
# Connecting to moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)|52.95.150.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29586716 (28M) [application/zip]
# Saving to: ‘images.zip.1’
#
# images.zip.1        100%[===================>]  28.22M  19.9MB/s    in 1.4s
#
# 2022-06-04 06:01:44 (19.9 MB/s) - ‘images.zip.1’ saved [29586716/29586716]
#
# replace images/castara.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
img = cv2.imread("/content/images/castara.jpeg")

imshow("Castara", img, size=6)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

imshow("Gray image", gray_img)

# %%
# print shape of grayscale image
gray_img.shape
# Out:
# (1280, 960)
